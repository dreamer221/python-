# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, decomposition

# %%
x1 = np.random.normal(1, 0.1, (25, 3))
x2 = np.random.normal(2, 0.1, (25, 3))
x3 = np.random.normal(3, 0.1, (25, 3))
x4 = np.random.normal(4, 0.1, (25, 3))
x = np.vstack((x1, x2, x3, x4))

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
colors = 'rgb'
markers = 'o*s'
ax.scatter(x[:, 0], x[:, 1], x[:, 2])
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
fig.suptitle("Iris After LDA")
plt.show()

# %%
pca = decomposition.PCA(n_components=2)  # 降维2维
# print(pca)
pca.fit(x)
x_2d = pca.transform(x)

plt.scatter(x_2d[:, 0], x_2d[:, 1])
plt.show()

# %%
pca = decomposition.PCA(n_components=1)  # 降维1维
pca.fit(x)
x_1d = pca.transform(x)
print(x_1d.ravel())
plt.scatter(range(len(x_1d)), x_1d)
plt.show()
# Out:
# [-2.53243815 -2.45769112 -2.67295477 -2.68091633 -2.56600751 -2.70607187
#  -2.74197219 -2.66034404 -2.55837466 -2.3481912  -2.7004811  -2.63735547
#  -2.64095222 -2.58184024 -2.5648764  -2.80034258 -2.54351933 -2.63352221
#  -2.52892008 -2.71729285 -2.78730338 -2.66941245 -2.67918988 -2.57660222
#  -2.58215587 -1.01040853 -0.9324933  -0.8280557  -0.82354306 -0.67987472
#  -0.85328526 -0.93090159 -0.9336828  -1.04964566 -0.90852711 -0.61865491
#  -0.94007735 -0.8026788  -0.90083405 -0.7803906  -0.63809748 -0.87926013
#  -0.81902816 -0.8916802  -0.86012153 -0.72051237 -0.7990377  -0.87346551
#  -0.83795939 -0.77380097  0.73207929  0.91376464  0.80132276  0.82624013
#   0.85669064  0.90853037  0.90629972  0.77504459  0.64836371  0.99085746
#   0.92314787  0.98213196  0.8184657   0.83738113  0.94409844  0.94596468
#   0.92997672  1.13221145  0.85668488  0.82859331  0.94805432  0.8980388
#   0.85695601  0.86150604  0.83131827  2.54017556  2.585861    2.43524515
#   2.52593138  2.60836035  2.46411064  2.44489306  2.44453323  2.64980244
#   2.58824346  2.61533507  2.71552544  2.68652552  2.59167431  2.66531251
#   2.6294568   2.68233881  2.54805755  2.61093606  2.69029301  2.55170091
#   2.5251103   2.87522713  2.55474243  2.47163001]
