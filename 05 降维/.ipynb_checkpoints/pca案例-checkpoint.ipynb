# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, decomposition

# %%
x1 = np.random.normal(1, 0.1, (25, 3))
x2 = np.random.normal(2, 0.1, (25, 3))
x3 = np.random.normal(3, 0.1, (25, 3))
x4 = np.random.normal(4, 0.1, (25, 3))
x = np.vstack((x1, x2, x3, x4))

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
colors = 'rgb'
markers = 'o*s'
ax.scatter(x[:, 0], x[:, 1], x[:, 2])
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
fig.suptitle("Iris After LDA")
plt.show()

# %%
pca = decomposition.PCA(n_components=2)  # 降维2维
pca.fit(x)
x_2d = pca.transform(x)

plt.scatter(x_2d[:, 0], x_2d[:, 1])
plt.show()

# %%
pca = decomposition.PCA(n_components=1)  # 降维1维
pca.fit(x)
x_1d = pca.transform(x)
print(x_1d.ravel())
plt.scatter(x_1d, [0] * len(x_1d) )
plt.show()
# Out:
# [-2.58283561 -2.78254233 -2.44701528 -2.46972776 -2.55317528 -2.6726435
#  -2.4122709  -2.6120792  -2.6381403  -2.61542522 -2.54063878 -2.59071634
#  -2.72743392 -2.67754941 -2.7669029  -2.65215917 -2.60819785 -2.63333855
#  -2.61128468 -2.75073673 -2.56891037 -2.62102225 -2.542726   -2.58398531
#  -2.74445111 -0.91425818 -0.9506223  -0.79843096 -0.91246576 -0.8240123
#  -0.82405751 -0.93398507 -0.98365807 -0.88819159 -0.76720901 -0.80052283
#  -0.83520495 -0.97463079 -0.95377257 -0.82987323 -0.75233905 -0.8776341
#  -0.85878938 -0.82599943 -0.86460338 -1.00233761 -0.85794902 -0.79563701
#  -0.84784321 -0.91987025  0.78163818  1.04880351  0.99308201  0.82237277
#   0.88837104  0.83332518  0.87069057  0.80083264  0.95322834  0.62659656
#   0.8804432   0.95972968  0.67044724  0.95301537  1.01876713  0.94926026
#   0.8004155   0.85569172  0.79222867  0.91086441  0.96842425  0.89484133
#   0.77457676  0.81262304  1.00270642  2.61372331  2.54926478  2.63153252
#   2.71616055  2.5724647   2.56777091  2.62444119  2.55556121  2.58891753
#   2.54367369  2.7929352   2.6190924   2.61093318  2.5461043   2.72279575
#   2.75752763  2.67424158  2.53666295  2.56405821  2.57716424  2.62676381
#   2.51483789  2.55351671  2.57635498  2.70033136]
